# %% [markdown]
# <div align="center">
#
# ### Lab 4
#
# # National Tsing Hua University
#
# #### Spring 2025
#
# #### 11320IEEM 513600
#
# #### Deep Learning and Industrial Applications
#
# ## Lab 4: Predicting Stock Price with Deep Learning
#
# </div>

# %% [markdown]
# ### Introduction
#
# In this lab, we explore the application of time-series datasets using Long Short-Term Memory (LSTM) networks, a type of recurrent neural network, to predict stock prices. Specifically, we will use historical price data from Nvidia to forecast the stock's price for the next day based on the prices of the previous N days. This approach is particularly relevant given the volatile nature of stock markets and the increasing reliance on automated trading systems.
#
# ### Objectives
#
# - To understand the fundamentals of LSTM networks and their application in time-series forecasting.
# - To develop a predictive model that can accurately forecast Nvidia's stock price for the next day using historical data.
#
# ### Dataset
#
# The dataset for this lab is from the "Huge Stock Market Dataset" available on Kaggle. This dataset includes daily prices and volumes for all US stocks and ETFs, with a specific focus on Nvidia (NVDA). The dataset features include:
#
# - **Date**: The recorded data points.
# - **Open**: The price at which the stock first traded upon the opening of an exchange on a given trading day.
# - **High**: The highest price at which the stock traded during the trading day.
# - **Low**: The lowest price at which the stock traded during the trading day.
# - **Close**: The price of the stock at closing time.
# - **Volume**: The number of shares or contracts traded in a security or an entire market during a given period.
# - **OpenInt**: The total number of outstanding derivative contracts, like options or futures. [More details here](https://www.kaggle.com/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/discussion/121096)
#
# ### References
#
# - [Huge Stock Market Dataset](https://www.kaggle.com/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs) for the dataset used in this lab.

# %% [markdown]
# ## A. Checking and Preprocessing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/deepLearning/HW4/nvda.us.txt')
df
# Out:
#             Date      Open      High       Low     Close    Volume  OpenInt
# 0     1999-01-22    1.6238    1.8092    1.4379    1.5215  18297633        0
# 1     1999-01-25    1.6423    1.6980    1.5215    1.6793   3445279        0
# 2     1999-01-26    1.6980    1.7350    1.5311    1.5494   2320993        0
# 3     1999-01-27    1.5586    1.5957    1.4660    1.5494   1662658        0
# 4     1999-01-28    1.5494    1.5586    1.5311    1.5401   1540110        0
# ...          ...       ...       ...       ...       ...       ...      ...
# 4728  2017-11-06  207.2000  209.9800  206.7000  209.6300   9731783        0
# 4729  2017-11-07  210.5500  212.9000  210.0560  212.0000  10671815        0
# 4730  2017-11-08  211.8500  212.0000  207.2400  209.1600  13033902        0
# 4731  2017-11-09  205.2700  206.3300  200.3700  205.3200  23895006        0
# 4732  2017-11-10  213.0800  218.6700  211.6300  216.1400  31300857        0
#
# [4733 rows x 7 columns]

# %%
plot = df.plot('Date', 'High', figsize=(15, 5))

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'OpenInt'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4733 entries, 0 to 4732
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     4733 non-null   object
#  1   Open     4733 non-null   float64
#  2   High     4733 non-null   float64
#  3   Low      4733 non-null   float64
#  4   Close    4733 non-null   float64
#  5   Volume   4733 non-null   int64
#  6   OpenInt  4733 non-null   int64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 259.0+ KB

# %%
# checking for null values
df.isnull().sum()
# Out:
# Date       0
# Open       0
# High       0
# Low        0
# Close      0
# Volume     0
# OpenInt    0
# dtype: int64

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (4733, 7)

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  4733.000000  4733.000000  4733.000000  4733.000000  4.733000e+03
# mean     20.796242    21.157332    20.420417    20.805404  1.615287e+07
# std      30.236284    30.615622    29.792958    30.263705  1.272446e+07
# min       1.298900     1.317500     1.233900     1.261900  0.000000e+00
# 25%       7.988300     8.247900     7.756400     7.978900  8.181100e+06
# 50%      12.963000    13.238000    12.721000    12.990000  1.390271e+07
# 75%      19.141000    19.418000    18.778000    19.106000  2.051602e+07
# max     213.080000   218.670000   211.630000   216.140000  2.496659e+08
#
#        OpenInt
# count   4733.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0

# %% [markdown]
# #### Converting the DataFrame to a NumPy Array

# %%
def create_sequences(input_data, output_data, window_size, step):
    sequences = []
    labels = []
    for i in range(0, len(input_data) - window_size, step):
        sequences.append(input_data[i:(i + window_size)])
        labels.append(output_data[i + window_size])
    return np.array(sequences), np.array(labels)

# %%
import numpy as np
import torch
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# Select features
features = df[['Open', 'High', 'Low', 'Close']]
# features = df[['Open', 'High', 'Low', 'Close', 'Volume']]
labels = df['High'].shift(-1)  # Next day's high price as label

# Initialize scaler
feature_scaler = MinMaxScaler()
label_scaler = MinMaxScaler()

# Fit and transform features
features_scaled = feature_scaler.fit_transform(features)

# Fit and transform labels (labels 也要正規化喔，因為是回歸問題)
labels_scaled = label_scaler.fit_transform(labels.values.reshape(-1, 1))

# 將 numpy 轉回 tensor
import torch

features_tensor = torch.tensor(features_scaled, dtype=torch.float32)
labels_tensor = torch.tensor(labels_scaled.squeeze(), dtype=torch.float32)

X, y = create_sequences(features, labels, window_size=20, step=10)

print(f'Shape of data X: {X.shape}')
print(f'Shape of data y: {y.shape}')

# split the hold-out tests
ind = np.linspace(0, len(X)-1, num=int(len(X)*0.1), dtype=int) # 10% hold-out
x_test = X[ind]
y_test = y[ind]
all_ind = np.arange(len(X))
remains_ind = np.delete(all_ind, ind)

X = X[remains_ind]
y = y[remains_ind]

# shuffle dataset
ind = np.random.permutation(len(X))
X = X[ind]
y = y[ind]
split_point = int(X.shape[0]*0.8)

x_train = X[:split_point]
y_train = y[:split_point]
x_val = X[split_point:]
y_val = y[split_point:]

print(f'Shape of data x_train: {x_train.shape}')
print(f'Shape of data y_train: {y_train.shape}')
print(f'Shape of data x_val: {x_val.shape}')
print(f'Shape of data y_val: {y_val.shape}')
print(f'Shape of data x_test: {x_test.shape}')
print(f'Shape of data y_test: {y_test.shape}')

# Convert to PyTorch tensors
x_train = torch.from_numpy(x_train).float()
y_train = torch.from_numpy(y_train).float()

x_val = torch.from_numpy(x_val).float()
y_val = torch.from_numpy(y_val).float()

x_test = torch.from_numpy(x_test).float()
y_test = torch.from_numpy(y_test).float()

batch_size = 32

# Create datasets
train_dataset = TensorDataset(x_train, y_train)
val_dataset = TensorDataset(x_val, y_val)
test_dataset = TensorDataset(x_test, y_test)

# Create dataloaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print(f'Number of samples in training and validation are {len(train_loader.dataset)} and {len(val_loader.dataset)}.')
# Out:
# Shape of data X: (472, 20, 4)
# Shape of data y: (472,)
# Shape of data x_train: (340, 20, 4)
# Shape of data y_train: (340,)
# Shape of data x_val: (85, 20, 4)
# Shape of data y_val: (85,)
# Shape of data x_test: (47, 20, 4)
# Shape of data y_test: (47,)
# Number of samples in training and validation are 340 and 85.

# %%
# print(len(features[0][0]))
# in_size = len(features[0][0])

# %% [markdown]
# ## B. Defining Neural Networks

# %%
import torch.nn as nn

class LSTMModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, output_dim):
        super().__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc(out[:, -1, :])
        return out

# %% [markdown]
# ## C. Training the Neural Network

# %%
# Check your GPU status.
# !nvidia-smi
# Out:
# Mon Apr 28 08:33:09 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   68C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR
from tqdm.auto import tqdm

train_losses = []
val_losses = []

epochs = 100
in_size = 4

model = LSTMModel(input_dim=in_size, hidden_dim=500, num_layers=2, output_dim=1).cuda()
print(model)

best_val_loss = float('inf')

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)
lr_scheduler = CosineAnnealingLR(optimizer, T_max=epochs, eta_min=0)

for epoch in tqdm(range(epochs)):
    # Training
    model.train()
    total_loss = 0.0

    for features, labels in train_loader:
        features = features.cuda()
        labels = labels.cuda()
        outputs = model(features).squeeze(-1)
        loss = criterion(outputs, labels)
        total_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # Learning rate update
    lr_scheduler.step()

    avg_train_loss = total_loss / len(train_loader)

    # Validation
    model.eval()
    total_val_loss = 0.0

    with torch.no_grad():
        for features, labels in val_loader:
            features = features.cuda()
            labels = labels.cuda()
            outputs = model(features).squeeze(-1)
            loss = criterion(outputs, labels)
            total_val_loss += loss.item()

    avg_val_loss = total_val_loss / len(val_loader)

    # Checkpoint
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        torch.save(model.state_dict(), 'best_model.pth')

    print(f'Epoch {epoch+1}/{epochs}, Train loss: {avg_train_loss:.4f}, Val loss: {avg_val_loss:.4f}, Best Val loss: {best_val_loss:.4f}')

    # Store performance
    train_losses.append(avg_train_loss)
    val_losses.append(avg_val_loss)
# Out:
# LSTMModel(
#   (lstm): LSTM(4, 500, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=500, out_features=1, bias=True)
# )
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 1/100, Train loss: 1075.6380, Val loss: 975.0213, Best Val loss: 975.0213
# Epoch 2/100, Train loss: 909.5027, Val loss: 938.1742, Best Val loss: 938.1742
# Epoch 3/100, Train loss: 859.3410, Val loss: 935.4479, Best Val loss: 935.4479
# Epoch 4/100, Train loss: 870.5264, Val loss: 935.0518, Best Val loss: 935.0518
# Epoch 5/100, Train loss: 918.7079, Val loss: 933.3817, Best Val loss: 933.3817
# Epoch 6/100, Train loss: 876.9393, Val loss: 929.6410, Best Val loss: 929.6410
# Epoch 7/100, Train loss: 840.7615, Val loss: 925.5836, Best Val loss: 925.5836
# Epoch 8/100, Train loss: 843.5798, Val loss: 921.7159, Best Val loss: 921.7159
# Epoch 9/100, Train loss: 877.7155, Val loss: 914.2411, Best Val loss: 914.2411
# Epoch 10/100, Train loss: 818.1120, Val loss: 895.5800, Best Val loss: 895.5800
# Epoch 11/100, Train loss: 790.0789, Val loss: 831.3145, Best Val loss: 831.3145
# Epoch 12/100, Train loss: 740.3997, Val loss: 757.6952, Best Val loss: 757.6952
# Epoch 13/100, Train loss: 653.9769, Val loss: 692.2679, Best Val loss: 692.2679
# Epoch 14/100, Train loss: 632.2647, Val loss: 635.3671, Best Val loss: 635.3671
# Epoch 15/100, Train loss: 564.4505, Val loss: 577.7541, Best Val loss: 577.7541
# Epoch 16/100, Train loss: 484.1181, Val loss: 529.5924, Best Val loss: 529.5924
# Epoch 17/100, Train loss: 466.3697, Val loss: 489.4961, Best Val loss: 489.4961
# Epoch 18/100, Train loss: 402.0925, Val loss: 452.1311, Best Val loss: 452.1311
# Epoch 19/100, Train loss: 368.4723, Val loss: 423.6511, Best Val loss: 423.6511
# Epoch 20/100, Train loss: 364.2514, Val loss: 398.0633, Best Val loss: 398.0633
# Epoch 21/100, Train loss: 341.3152, Val loss: 374.0002, Best Val loss: 374.0002
# Epoch 22/100, Train loss: 294.6804, Val loss: 350.9756, Best Val loss: 350.9756
# Epoch 23/100, Train loss: 276.5714, Val loss: 329.9079, Best Val loss: 329.9079
# Epoch 24/100, Train loss: 255.2989, Val loss: 312.5409, Best Val loss: 312.5409
# Epoch 25/100, Train loss: 239.7543, Val loss: 297.1572, Best Val loss: 297.1572
# Epoch 26/100, Train loss: 265.9105, Val loss: 290.3061, Best Val loss: 290.3061
# Epoch 27/100, Train loss: 219.5079, Val loss: 267.0074, Best Val loss: 267.0074
# Epoch 28/100, Train loss: 200.2851, Val loss: 253.1087, Best Val loss: 253.1087
# Epoch 29/100, Train loss: 193.5017, Val loss: 248.9173, Best Val loss: 248.9173
# Epoch 30/100, Train loss: 189.1261, Val loss: 229.0787, Best Val loss: 229.0787
# Epoch 31/100, Train loss: 175.3447, Val loss: 233.8661, Best Val loss: 229.0787
# Epoch 32/100, Train loss: 171.7907, Val loss: 210.1428, Best Val loss: 210.1428
# Epoch 33/100, Train loss: 151.7132, Val loss: 202.0931, Best Val loss: 202.0931
# Epoch 34/100, Train loss: 145.0896, Val loss: 193.1007, Best Val loss: 193.1007
# Epoch 35/100, Train loss: 140.1530, Val loss: 191.4099, Best Val loss: 191.4099
# Epoch 36/100, Train loss: 159.1990, Val loss: 177.5918, Best Val loss: 177.5918
# Epoch 37/100, Train loss: 125.8275, Val loss: 168.1231, Best Val loss: 168.1231
# Epoch 38/100, Train loss: 119.6330, Val loss: 163.4664, Best Val loss: 163.4664
# Epoch 39/100, Train loss: 122.5508, Val loss: 156.5157, Best Val loss: 156.5157
# Epoch 40/100, Train loss: 110.8332, Val loss: 151.4514, Best Val loss: 151.4514
# Epoch 41/100, Train loss: 114.0911, Val loss: 147.0233, Best Val loss: 147.0233
# Epoch 42/100, Train loss: 103.5513, Val loss: 141.5612, Best Val loss: 141.5612
# Epoch 43/100, Train loss: 106.6778, Val loss: 143.1344, Best Val loss: 141.5612
# Epoch 44/100, Train loss: 97.1259, Val loss: 132.5727, Best Val loss: 132.5727
# Epoch 45/100, Train loss: 93.9377, Val loss: 129.0707, Best Val loss: 129.0707
# Epoch 46/100, Train loss: 107.8244, Val loss: 126.0594, Best Val loss: 126.0594
# Epoch 47/100, Train loss: 96.3723, Val loss: 121.8139, Best Val loss: 121.8139
# Epoch 48/100, Train loss: 86.8732, Val loss: 120.2480, Best Val loss: 120.2480
# Epoch 49/100, Train loss: 85.3664, Val loss: 118.5971, Best Val loss: 118.5971
# Epoch 50/100, Train loss: 81.3791, Val loss: 114.8997, Best Val loss: 114.8997
# Epoch 51/100, Train loss: 78.9534, Val loss: 110.9918, Best Val loss: 110.9918
# Epoch 52/100, Train loss: 77.0488, Val loss: 108.8444, Best Val loss: 108.8444
# Epoch 53/100, Train loss: 79.9913, Val loss: 105.2979, Best Val loss: 105.2979
# Epoch 54/100, Train loss: 75.3048, Val loss: 102.8475, Best Val loss: 102.8475
# Epoch 55/100, Train loss: 71.6572, Val loss: 101.9376, Best Val loss: 101.9376
# Epoch 56/100, Train loss: 77.5127, Val loss: 99.8861, Best Val loss: 99.8861
# Epoch 57/100, Train loss: 71.7411, Val loss: 96.6366, Best Val loss: 96.6366
# Epoch 58/100, Train loss: 68.8319, Val loss: 95.5197, Best Val loss: 95.5197
# Epoch 59/100, Train loss: 67.7391, Val loss: 92.7808, Best Val loss: 92.7808
# Epoch 60/100, Train loss: 63.1182, Val loss: 90.5431, Best Val loss: 90.5431
# Epoch 61/100, Train loss: 67.7466, Val loss: 89.6617, Best Val loss: 89.6617
# Epoch 62/100, Train loss: 60.1563, Val loss: 89.2795, Best Val loss: 89.2795
# Epoch 63/100, Train loss: 59.1449, Val loss: 86.8660, Best Val loss: 86.8660
# Epoch 64/100, Train loss: 58.1808, Val loss: 85.3188, Best Val loss: 85.3188
# Epoch 65/100, Train loss: 57.6057, Val loss: 83.3452, Best Val loss: 83.3452
# Epoch 66/100, Train loss: 56.6633, Val loss: 84.4414, Best Val loss: 83.3452
# Epoch 67/100, Train loss: 55.1975, Val loss: 81.6900, Best Val loss: 81.6900
# Epoch 68/100, Train loss: 54.4055, Val loss: 80.9598, Best Val loss: 80.9598
# Epoch 69/100, Train loss: 53.8582, Val loss: 79.7871, Best Val loss: 79.7871
# Epoch 70/100, Train loss: 52.5962, Val loss: 78.5165, Best Val loss: 78.5165
# Epoch 71/100, Train loss: 51.9914, Val loss: 78.0746, Best Val loss: 78.0746
# Epoch 72/100, Train loss: 51.3395, Val loss: 76.8869, Best Val loss: 76.8869
# Epoch 73/100, Train loss: 50.6021, Val loss: 76.0050, Best Val loss: 76.0050
# Epoch 74/100, Train loss: 50.0659, Val loss: 75.4930, Best Val loss: 75.4930
# Epoch 75/100, Train loss: 51.9299, Val loss: 74.7593, Best Val loss: 74.7593
# Epoch 76/100, Train loss: 49.0945, Val loss: 74.0557, Best Val loss: 74.0557
# Epoch 77/100, Train loss: 48.5207, Val loss: 73.7969, Best Val loss: 73.7969
# Epoch 78/100, Train loss: 53.0795, Val loss: 73.4207, Best Val loss: 73.4207
# Epoch 79/100, Train loss: 47.6796, Val loss: 72.5201, Best Val loss: 72.5201
# Epoch 80/100, Train loss: 47.2754, Val loss: 72.1255, Best Val loss: 72.1255
# Epoch 81/100, Train loss: 47.3817, Val loss: 71.4816, Best Val loss: 71.4816
# Epoch 82/100, Train loss: 46.7687, Val loss: 71.7680, Best Val loss: 71.4816
# Epoch 83/100, Train loss: 50.2312, Val loss: 71.3960, Best Val loss: 71.3960
# Epoch 84/100, Train loss: 46.2160, Val loss: 70.5641, Best Val loss: 70.5641
# Epoch 85/100, Train loss: 48.7232, Val loss: 70.1997, Best Val loss: 70.1997
# Epoch 86/100, Train loss: 52.2418, Val loss: 70.2546, Best Val loss: 70.1997
# Epoch 87/100, Train loss: 45.7696, Val loss: 70.0225, Best Val loss: 70.0225
# Epoch 88/100, Train loss: 45.4390, Val loss: 69.8990, Best Val loss: 69.8990
# Epoch 89/100, Train loss: 48.2643, Val loss: 69.7833, Best Val loss: 69.7833
# Epoch 90/100, Train loss: 45.5902, Val loss: 69.4927, Best Val loss: 69.4927
# Epoch 91/100, Train loss: 45.1923, Val loss: 69.5616, Best Val loss: 69.4927
# Epoch 92/100, Train loss: 45.0471, Val loss: 69.3853, Best Val loss: 69.3853
# Epoch 93/100, Train loss: 55.2286, Val loss: 69.3226, Best Val loss: 69.3226
# Epoch 94/100, Train loss: 44.9224, Val loss: 69.2248, Best Val loss: 69.2248
# Epoch 95/100, Train loss: 44.8773, Val loss: 69.2144, Best Val loss: 69.2144
# Epoch 96/100, Train loss: 45.0497, Val loss: 69.1524, Best Val loss: 69.1524
# Epoch 97/100, Train loss: 44.8369, Val loss: 69.1707, Best Val loss: 69.1524
# Epoch 98/100, Train loss: 47.4436, Val loss: 69.1577, Best Val loss: 69.1524
# Epoch 99/100, Train loss: 47.7436, Val loss: 69.1542, Best Val loss: 69.1524
# Epoch 100/100, Train loss: 46.8666, Val loss: 69.1534, Best Val loss: 69.1524

# %% [markdown]
# #### Visualizing the model performance

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(train_losses)
plt.plot(val_losses)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Val'])

plt.show()

# %% [markdown]
# ## D. Evaluating Your Trained Model

# %%
# Load the trained weights
model.load_state_dict(torch.load('best_model.pth'))

# Set the model to evaluation mode
model.eval()

test_correct = 0
test_total = 0

pred_value = []
actual_value = []

with torch.no_grad():
    for features, labels in test_loader:
        features = features.cuda()
        outputs = model(features).squeeze(-1)
        pred_value.append(outputs.cpu())
        actual_value.append(labels)

pred_value = torch.cat(pred_value)
actual_value = torch.cat(actual_value)

# %%
plt.figure(figsize=(10, 5))
plt.plot(pred_value[:])
plt.plot(actual_value[:])
plt.xlabel('Day')
plt.ylabel('Price')
plt.legend(['Pred', 'Actual'])

plt.show()

# %%
import torch.nn.functional as F

# 計算 MSE
mse = F.mse_loss(pred_value, actual_value)

print(f"Test MSE: {mse.item():.4f}")
# Out:
# Test MSE: 145.8969

# %%
# !pip install torchmetrics

# %%
# from torchmetrics import MeanSquaredError

# mse_metric = MeanSquaredError()
# mse = mse_metric(pred_value, actual_value)

# print(f"Test MSE: {mse.item():.4f}")
